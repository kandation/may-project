# %%
import pandas as pd

# %%
# read output directory
import os

list_of_dirs = os.listdir('outputs')
names = set()
for dirx in list_of_dirs:
    # list csv file in dir
    directory = os.path.join('outputs', dirx)
    files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.csv')]
    for file in files:
        # get file name
        file_name = os.path.basename(file)
        file_name = file_name.replace('.csv', '')
        names.add(file_name)


# for name in names:
#     print(f"'{name}':'',")

map_names = {
    'สถานีหลัก': 'main_station',
    'บ้านห้วยฝาย': 'บ้านห้วยฝาย',
    'บ้านเสด็จ': 'บ้านเสด็จ',
    'Maechang': 'แม่เชียง',
    'ศูนย์ราชการแม่เมาะ station': 'gov_meamao',
    'BanHuayking': 'บ้านห้วยคิง',
    'สถานีตรวจอากาศหลัก': 'main_station',
    'Mainstation': 'main_station',
    'บ้านท่าสี station': 'บ้านท่าสี',
    'Bansoppad': 'บ้านสบป้าด',
    'บ้านใหม่รัตนโกสินทร์': 'บ้านใหม่รัตนโกสินทร์',
    'Government center': 'gov_center',
    'บ้านสบป้าด station': 'บ้านสบป้าด',
    'Banhanghung': 'บ้านหางฮุง',
    'BanHuaFai': 'บ้านหัวฝาย',
    'ประตูผา station': 'ประตูผา',
    'Pratupha': 'ประตูผา',
    'บ้านใหม่รัตนโกสินทร์ station': 'บ้านใหม่รัตนโกสินทร์',
    'Banmairattanakosin': 'บ้านใหม่รัตนโกสินทร์',
    'บ้านสบเมาะ': 'บ้านสบเมาะ',
    'บ้านท่าสี': 'บ้านท่าสี',
    'Banhuafai': 'บ้านหัวฝาย',
    'Bansopmoe': 'บ้านสบโม',
    'บ้านหางฮุง station': 'บ้านหางฮุง',
    'Banmaechang': 'บ้านแม่จาง',
    'Banmairattakosin': '',
    'บ้านแม่จาง': 'บ้านแม่จาง',
    'Bansadej': 'บ้านเสด็จ',
    'บ้านหางฮุง': 'บ้านหางฮุง',
    'BanHuaiking': 'บ้านห้วยคิง',
    'ประตูผา': 'ประตูผา',
    'ศูนย์ราชการแม่เมาะ': 'gov_meamao',
    'บ้านหัวฝาย': 'บ้านหัวฝาย',
    'บ้านสบป้าด': 'บ้านสบป้าด',
    'Main station': 'main_station',
    'บ้านห้วยคิง': 'บ้านห้วยคิง',
    'Banthasii': 'บ้านท่าสี',
}

# replace map names
for dirx in list_of_dirs:
# list csv file in dir
    directory = os.path.join('outputs', dirx)
    files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.csv')]
    for file in files:
        # get file name
        file_name = os.path.basename(file)
        file_name = file_name.replace('.csv', '')
        os.rename(file, os.path.join(directory, map_names[file_name] + '.csv'))
        print(file_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 69
#      67 file_name = os.path.basename(file)
#      68 file_name = file_name.replace('.csv', '')
# ---> 69 os.rename(file, os.path.join(directory, map_names[file_name] + '.csv'))
#      70 print(file_name)
#
# KeyError: 'gov_meamao'

# %%
# Merge

for dirx in list_of_dirs:
# list csv file in dir
    directory = os.path.join('outputs', dirx)
    files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.csv')]
    for file in files:
        print(file)
# Out:
# outputs\BP\gov_meamao.csv
# outputs\BP\main_station.csv
# outputs\BP\บ้านท่าสี.csv
# outputs\BP\บ้านสบป้าด.csv
# outputs\BP\บ้านสบเมาะ.csv
# outputs\BP\บ้านหัวฝาย.csv
# outputs\BP\บ้านหางฮุง.csv
# outputs\BP\บ้านห้วยคิง.csv
# outputs\BP\บ้านเสด็จ.csv
# outputs\BP\บ้านแม่จาง.csv
# outputs\BP\บ้านใหม่รัตนโกสินทร์.csv
# outputs\BP\ประตูผา.csv
# outputs\DEV\gov_meamao.csv
# outputs\DEV\main_station.csv
# outputs\DEV\บ้านท่าสี.csv
# outputs\DEV\บ้านสบป้าด.csv
# outputs\DEV\บ้านสบเมาะ.csv
# outputs\DEV\บ้านหัวฝาย.csv
# outputs\DEV\บ้านหางฮุง.csv
# outputs\DEV\บ้านห้วยคิง.csv
# outputs\DEV\บ้านเสด็จ.csv
# outputs\DEV\บ้านแม่จาง.csv
# outputs\DEV\บ้านใหม่รัตนโกสินทร์.csv
# outputs\DEV\ประตูผา.csv
# outputs\NO2_2009-2019\gov_center.csv
# outputs\NO2_2009-2019\main_station.csv
# outputs\NO2_2009-2019\บ้านท่าสี.csv
# outputs\NO2_2009-2019\บ้านสบป้าด.csv
# outputs\NO2_2009-2019\บ้านสบโม.csv
# outputs\NO2_2009-2019\บ้านหัวฝาย.csv
# outputs\NO2_2009-2019\บ้านห้วยคิง.csv
# outputs\NO2_2009-2019\บ้านเสด็จ.csv
# outputs\NO2_2009-2019\บ้านแม่จาง.csv
# outputs\NO2_2009-2019\บ้านใหม่รัตนโกสินทร์.csv
# outputs\NO2_2009-2019\ประตูผา.csv
# outputs\PM10_2009-2019\gov_center.csv
# outputs\PM10_2009-2019\main_station.csv
# outputs\PM10_2009-2019\บ้านสบป้าด.csv
# outputs\PM10_2009-2019\บ้านสบโม.csv
# outputs\PM10_2009-2019\บ้านหัวฝาย.csv
# outputs\PM10_2009-2019\บ้านแม่จาง.csv
# outputs\RAIN\gov_meamao.csv
# outputs\RAIN\main_station.csv
# outputs\RAIN\บ้านท่าสี.csv
# outputs\RAIN\บ้านสบป้าด.csv
# outputs\RAIN\บ้านสบเมาะ.csv
# outputs\RAIN\บ้านหัวฝาย.csv
# outputs\RAIN\บ้านห้วยคิง.csv
# outputs\RAIN\บ้านเสด็จ.csv
# outputs\RAIN\บ้านแม่จาง.csv
# outputs\RAIN\บ้านใหม่รัตนโกสินทร์.csv
# outputs\RAIN\ประตูผา.csv
# outputs\RH\gov_meamao.csv
# outputs\RH\main_station.csv
# outputs\RH\บ้านท่าสี.csv
# outputs\RH\บ้านสบป้าด.csv
# outputs\RH\บ้านสบเมาะ.csv
# outputs\RH\บ้านหัวฝาย.csv
# outputs\RH\บ้านหางฮุง.csv
# outputs\RH\บ้านห้วยคิง.csv
# outputs\RH\บ้านเสด็จ.csv
# outputs\RH\บ้านแม่จาง.csv
# outputs\RH\บ้านใหม่รัตนโกสินทร์.csv
# outputs\RH\ประตูผา.csv
# outputs\SO2_2009\.csv
# outputs\SO2_2009\gov_center.csv
# outputs\SO2_2009\main_station.csv
# outputs\SO2_2009\บ้านท่าสี.csv
# outputs\SO2_2009\บ้านสบป้าด.csv
# outputs\SO2_2009\บ้านสบโม.csv
# outputs\SO2_2009\บ้านหัวฝาย.csv
# outputs\SO2_2009\บ้านหางฮุง.csv
# outputs\SO2_2009\บ้านห้วยคิง.csv
# outputs\SO2_2009\บ้านเสด็จ.csv
# outputs\SO2_2009\บ้านแม่จาง.csv
# outputs\SO2_2009\แม่เชียง.csv
# outputs\SO2_2010-2020\gov_meamao.csv
# outputs\SO2_2010-2020\บ้านท่าสี.csv
# outputs\SO2_2010-2020\บ้านสบป้าด.csv
# outputs\SO2_2010-2020\บ้านสบเมาะ.csv
# outputs\SO2_2010-2020\บ้านหางฮุง.csv
# outputs\SO2_2010-2020\บ้านห้วยคิง.csv
# outputs\SO2_2010-2020\บ้านห้วยฝาย.csv
# outputs\SO2_2010-2020\บ้านเสด็จ.csv
# outputs\SO2_2010-2020\บ้านแม่จาง.csv
# outputs\SO2_2010-2020\บ้านใหม่รัตนโกสินทร์.csv
# outputs\SO2_2010-2020\ประตูผา.csv
# outputs\SW\gov_meamao.csv
# outputs\SW\บ้านท่าสี.csv
# outputs\SW\บ้านสบป้าด.csv
# outputs\SW\บ้านสบเมาะ.csv
# outputs\SW\บ้านหัวฝาย.csv
# outputs\SW\บ้านหางฮุง.csv
# outputs\SW\บ้านห้วยคิง.csv
# outputs\SW\บ้านเสด็จ.csv
# outputs\TEMP\gov_meamao.csv
# outputs\TEMP\main_station.csv
# outputs\TEMP\บ้านท่าสี.csv
# outputs\TEMP\บ้านสบป้าด.csv
# outputs\TEMP\บ้านสบเมาะ.csv
# outputs\TEMP\บ้านหางฮุง.csv
# outputs\TEMP\บ้านห้วยคิง.csv
# outputs\TEMP\บ้านห้วยฝาย.csv
# outputs\TEMP\บ้านเสด็จ.csv
# outputs\TEMP\บ้านแม่จาง.csv
# outputs\TEMP\บ้านใหม่รัตนโกสินทร์.csv
# outputs\TEMP\ประตูผา.csv
# outputs\TSP_2009-2019\gov_center.csv
# outputs\TSP_2009-2019\main_station.csv
# outputs\TSP_2009-2019\บ้านสบป้าด.csv
# outputs\TSP_2009-2019\บ้านสบโม.csv
# outputs\TSP_2009-2019\บ้านหัวฝาย.csv
# outputs\TSP_2009-2019\บ้านห้วยคิง.csv
# outputs\TSP_2009-2019\บ้านเสด็จ.csv
# outputs\TSP_2009-2019\บ้านแม่จาง.csv
# outputs\TSP_2009-2019\บ้านใหม่รัตนโกสินทร์.csv
# outputs\TSP_2009-2019\ประตูผา.csv
# outputs\WD\gov_meamao.csv
# outputs\WD\บ้านท่าสี.csv
# outputs\WD\บ้านสบป้าด.csv
# outputs\WD\บ้านสบเมาะ.csv
# outputs\WD\บ้านหางฮุง.csv
# outputs\WD\บ้านห้วยคิง.csv
# outputs\WD\บ้านห้วยฝาย.csv
# outputs\WD\บ้านเสด็จ.csv
# outputs\WD\บ้านแม่จาง.csv
# outputs\WD\บ้านใหม่รัตนโกสินทร์.csv
# outputs\WD\ประตูผา.csv
# outputs\WS\gov_meamao.csv
# outputs\WS\บ้านท่าสี.csv
# outputs\WS\บ้านสบป้าด.csv
# outputs\WS\บ้านสบเมาะ.csv
# outputs\WS\บ้านหัวฝาย.csv
# outputs\WS\บ้านหางฮุง.csv
# outputs\WS\บ้านห้วยคิง.csv
# outputs\WS\บ้านเสด็จ.csv
# outputs\WS\บ้านแม่จาง.csv
# outputs\WS\บ้านใหม่รัตนโกสินทร์.csv
# outputs\WS\ประตูผา.csv

# %%
import os
import pandas as pd

merged_data = {}

for dirx in list_of_dirs:
    # list csv files in the directory
    directory = os.path.join('outputs', dirx)
    files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.csv')]

    for file_path in files:
        file_name = os.path.basename(file_path)

        if file_name not in merged_data:
            merged_data[file_name] = []
        merged_data[file_name].append(file_path)

# # Merge and save
for file_name, paths in merged_data.items():
    dfs = [pd.read_csv(path) for path in paths]
    merged_df = pd.concat(dfs, ignore_index=True)
    # merged_df.to_csv(os.path.join('merged_outputs', file_name), index=False)
    print(merged_df)

merged_data
# Out:
#         Year             Datetime   Value  ValueLn
# 0       2010  2010-01-01 01:00:00  964.00   964.00
# 1       2010  2010-01-01 02:00:00  964.00   964.00
# 2       2010  2010-01-01 03:00:00  963.00   963.00
# 3       2010  2010-01-01 04:00:00  963.00   963.00
# 4       2010  2010-01-01 05:00:00  963.00   963.00
# ...      ...                  ...     ...      ...
# 843859  2020  2020-12-31 20:00:00    0.29     0.29
# 843860  2020  2020-12-31 21:00:00    0.09     0.09
# 843861  2020  2020-12-31 22:00:00    0.42     0.42
# 843862  2020  2020-12-31 23:00:00    0.38     0.38
# 843863  2021  2021-01-01 00:00:00    0.42     0.42
#
# [843864 rows x 4 columns]
#         Year             Datetime  Value  ValueLn
# 0       2010  2010-01-01 01:00:00  972.0    972.0
# 1       2010  2010-01-01 02:00:00  971.0    971.0
# 2       2010  2010-01-01 03:00:00  971.0    971.0
# 3       2010  2010-01-01 04:00:00  971.0    971.0
# 4       2010  2010-01-01 05:00:00  971.0    971.0
# ...      ...                  ...    ...      ...
# 719539  2019  2019-12-31 20:00:00   95.0     95.0
# 719540  2019  2019-12-31 21:00:00   61.0     61.0
# 719541  2019  2019-12-31 22:00:00   64.0     64.0
# 719542  2019  2019-12-31 23:00:00   75.0     75.0
# 719543  2020  2020-01-01 00:00:00   44.0     44.0
#
# [719544 rows x 4 columns]
#         Year             Datetime   Value  ValueLn
# 0       2010  2010-01-01 01:00:00  967.00   967.00
# 1       2010  2010-01-01 02:00:00  967.00   967.00
# 2       2010  2010-01-01 03:00:00  966.00   966.00
# 3       2010  2010-01-01 04:00:00  966.00   966.00
# 4       2010  2010-01-01 05:00:00  966.00   966.00
# ...      ...                  ...     ...      ...
# 973051  2020  2020-12-31 20:00:00    0.05     0.05
# 973052  2020  2020-12-31 21:00:00    0.25     0.25
# 973053  2020  2020-12-31 22:00:00    0.26     0.26
# 973054  2020  2020-12-31 23:00:00    0.23     0.23
# 973055  2021  2021-01-01 00:00:00    0.15     0.15
#
# [973056 rows x 4 columns]
#          Year             Datetime   Value  ValueLn
# 0        2010  2010-01-01 01:00:00  970.00   970.00
# 1        2010  2010-01-01 02:00:00  969.00   969.00
# [289296 rows x 4 columns]
# {'gov_meamao.csv': ['outputs\\BP\\gov_meamao.csv',
#   'outputs\\DEV\\gov_meamao.csv',
#   'outputs\\RAIN\\gov_meamao.csv',
#   'outputs\\RH\\gov_meamao.csv',
#   'outputs\\SO2_2010-2020\\gov_meamao.csv',
#   'outputs\\SW\\gov_meamao.csv',
#   'outputs\\TEMP\\gov_meamao.csv',
#   'outputs\\WD\\gov_meamao.csv',
#   'outputs\\WS\\gov_meamao.csv'],
#  'main_station.csv': ['outputs\\BP\\main_station.csv',
#   'outputs\\DEV\\main_station.csv',
#   'outputs\\NO2_2009-2019\\main_station.csv',
#   'outputs\\PM10_2009-2019\\main_station.csv',
#   'outputs\\RAIN\\main_station.csv',
#   'outputs\\RH\\main_station.csv',
#   'outputs\\SO2_2009\\main_station.csv',
#   'outputs\\TEMP\\main_station.csv',
#   'outputs\\TSP_2009-2019\\main_station.csv'],
#  'บ้านท่าสี.csv': ['outputs\\BP\\บ้านท่าสี.csv',
#   'outputs\\DEV\\บ้านท่าสี.csv',
#   'outputs\\NO2_2009-2019\\บ้านท่าสี.csv',
#   'outputs\\RAIN\\บ้านท่าสี.csv',
#   'outputs\\RH\\บ้านท่าสี.csv',
#   'outputs\\SO2_2009\\บ้านท่าสี.csv',
#   'outputs\\SO2_2010-2020\\บ้านท่าสี.csv',
#   'outputs\\SW\\บ้านท่าสี.csv',
#   'outputs\\TEMP\\บ้านท่าสี.csv',
#   'outputs\\WD\\บ้านท่าสี.csv',
#   'outputs\\WS\\บ้านท่าสี.csv'],
#  'บ้านสบป้าด.csv': ['outputs\\BP\\บ้านสบป้าด.csv',
#   'outputs\\DEV\\บ้านสบป้าด.csv',
#   'outputs\\NO2_2009-2019\\บ้านสบป้าด.csv',
#   'outputs\\PM10_2009-2019\\บ้านสบป้าด.csv',
#   'outputs\\RAIN\\บ้านสบป้าด.csv',
#   'outputs\\RH\\บ้านสบป้าด.csv',
#   'outputs\\SO2_2009\\บ้านสบป้าด.csv',
#   'outputs\\SO2_2010-2020\\บ้านสบป้าด.csv',
#   'outputs\\SW\\บ้านสบป้าด.csv',
#   'outputs\\TEMP\\บ้านสบป้าด.csv',
#   'outputs\\TSP_2009-2019\\บ้านสบป้าด.csv',
#   'outputs\\WD\\บ้านสบป้าด.csv',
#   'outputs\\WS\\บ้านสบป้าด.csv'],
#  'บ้านสบเมาะ.csv': ['outputs\\BP\\บ้านสบเมาะ.csv',
#   'outputs\\DEV\\บ้านสบเมาะ.csv',
#   'outputs\\RAIN\\บ้านสบเมาะ.csv',
#   'outputs\\RH\\บ้านสบเมาะ.csv',
#   'outputs\\SO2_2010-2020\\บ้านสบเมาะ.csv',
#   'outputs\\SW\\บ้านสบเมาะ.csv',
#   'outputs\\TEMP\\บ้านสบเมาะ.csv',
#   'outputs\\WD\\บ้านสบเมาะ.csv',
#   'outputs\\WS\\บ้านสบเมาะ.csv'],
#  'บ้านหัวฝาย.csv': ['outputs\\BP\\บ้านหัวฝาย.csv',
#   'outputs\\DEV\\บ้านหัวฝาย.csv',
#   'outputs\\NO2_2009-2019\\บ้านหัวฝาย.csv',
#   'outputs\\PM10_2009-2019\\บ้านหัวฝาย.csv',
#   'outputs\\RAIN\\บ้านหัวฝาย.csv',
#   'outputs\\RH\\บ้านหัวฝาย.csv',
#   'outputs\\SO2_2009\\บ้านหัวฝาย.csv',
#   'outputs\\SW\\บ้านหัวฝาย.csv',
#   'outputs\\TSP_2009-2019\\บ้านหัวฝาย.csv',
#   'outputs\\WS\\บ้านหัวฝาย.csv'],
#  'บ้านหางฮุง.csv': ['outputs\\BP\\บ้านหางฮุง.csv',
#   'outputs\\DEV\\บ้านหางฮุง.csv',
#   'outputs\\RH\\บ้านหางฮุง.csv',
#   'outputs\\SO2_2009\\บ้านหางฮุง.csv',
#   'outputs\\SO2_2010-2020\\บ้านหางฮุง.csv',
#   'outputs\\SW\\บ้านหางฮุง.csv',
#   'outputs\\TEMP\\บ้านหางฮุง.csv',
#   'outputs\\WD\\บ้านหางฮุง.csv',
#   'outputs\\WS\\บ้านหางฮุง.csv'],
#  'บ้านห้วยคิง.csv': ['outputs\\BP\\บ้านห้วยคิง.csv',
#   'outputs\\DEV\\บ้านห้วยคิง.csv',
#   'outputs\\NO2_2009-2019\\บ้านห้วยคิง.csv',
#   'outputs\\RAIN\\บ้านห้วยคิง.csv',
#   'outputs\\RH\\บ้านห้วยคิง.csv',
#   'outputs\\SO2_2009\\บ้านห้วยคิง.csv',
#   'outputs\\SO2_2010-2020\\บ้านห้วยคิง.csv',
#   'outputs\\SW\\บ้านห้วยคิง.csv',
#   'outputs\\TEMP\\บ้านห้วยคิง.csv',
#   'outputs\\TSP_2009-2019\\บ้านห้วยคิง.csv',
#   'outputs\\WD\\บ้านห้วยคิง.csv',
#   'outputs\\WS\\บ้านห้วยคิง.csv'],
#  'บ้านเสด็จ.csv': ['outputs\\BP\\บ้านเสด็จ.csv',
#   'outputs\\DEV\\บ้านเสด็จ.csv',
#   'outputs\\NO2_2009-2019\\บ้านเสด็จ.csv',
#   'outputs\\RAIN\\บ้านเสด็จ.csv',
#   'outputs\\RH\\บ้านเสด็จ.csv',
#   'outputs\\SO2_2009\\บ้านเสด็จ.csv',
#   'outputs\\SO2_2010-2020\\บ้านเสด็จ.csv',
#   'outputs\\SW\\บ้านเสด็จ.csv',
#   'outputs\\TEMP\\บ้านเสด็จ.csv',
#   'outputs\\TSP_2009-2019\\บ้านเสด็จ.csv',
#   'outputs\\WD\\บ้านเสด็จ.csv',
#   'outputs\\WS\\บ้านเสด็จ.csv'],
#  'บ้านแม่จาง.csv': ['outputs\\BP\\บ้านแม่จาง.csv',
#   'outputs\\DEV\\บ้านแม่จาง.csv',
#   'outputs\\NO2_2009-2019\\บ้านแม่จาง.csv',
#   'outputs\\PM10_2009-2019\\บ้านแม่จาง.csv',
#   'outputs\\RAIN\\บ้านแม่จาง.csv',
#   'outputs\\RH\\บ้านแม่จาง.csv',
#   'outputs\\SO2_2009\\บ้านแม่จาง.csv',
#   'outputs\\SO2_2010-2020\\บ้านแม่จาง.csv',
#   'outputs\\TEMP\\บ้านแม่จาง.csv',
#   'outputs\\TSP_2009-2019\\บ้านแม่จาง.csv',
#   'outputs\\WD\\บ้านแม่จาง.csv',
#   'outputs\\WS\\บ้านแม่จาง.csv'],
#  'บ้านใหม่รัตนโกสินทร์.csv': ['outputs\\BP\\บ้านใหม่รัตนโกสินทร์.csv',
#   'outputs\\DEV\\บ้านใหม่รัตนโกสินทร์.csv',
#   'outputs\\NO2_2009-2019\\บ้านใหม่รัตนโกสินทร์.csv',
#   'outputs\\RAIN\\บ้านใหม่รัตนโกสินทร์.csv',
#   'outputs\\RH\\บ้านใหม่รัตนโกสินทร์.csv',
#   'outputs\\SO2_2010-2020\\บ้านใหม่รัตนโกสินทร์.csv',
#   'outputs\\TEMP\\บ้านใหม่รัตนโกสินทร์.csv',
#   'outputs\\TSP_2009-2019\\บ้านใหม่รัตนโกสินทร์.csv',
#   'outputs\\WD\\บ้านใหม่รัตนโกสินทร์.csv',
#   'outputs\\WS\\บ้านใหม่รัตนโกสินทร์.csv'],
#  'ประตูผา.csv': ['outputs\\BP\\ประตูผา.csv',
#   'outputs\\DEV\\ประตูผา.csv',
#   'outputs\\NO2_2009-2019\\ประตูผา.csv',
#   'outputs\\RAIN\\ประตูผา.csv',
#   'outputs\\RH\\ประตูผา.csv',
#   'outputs\\SO2_2010-2020\\ประตูผา.csv',
#   'outputs\\TEMP\\ประตูผา.csv',
#   'outputs\\TSP_2009-2019\\ประตูผา.csv',
#   'outputs\\WD\\ประตูผา.csv',
#   'outputs\\WS\\ประตูผา.csv'],
#  'gov_center.csv': ['outputs\\NO2_2009-2019\\gov_center.csv',
#   'outputs\\PM10_2009-2019\\gov_center.csv',
#   'outputs\\SO2_2009\\gov_center.csv',
#   'outputs\\TSP_2009-2019\\gov_center.csv'],
#  'บ้านสบโม.csv': ['outputs\\NO2_2009-2019\\บ้านสบโม.csv',
#   'outputs\\PM10_2009-2019\\บ้านสบโม.csv',
#   'outputs\\SO2_2009\\บ้านสบโม.csv',
#   'outputs\\TSP_2009-2019\\บ้านสบโม.csv'],
#  '.csv': ['outputs\\SO2_2009\\.csv'],
#  'แม่เชียง.csv': ['outputs\\SO2_2009\\แม่เชียง.csv'],
#  'บ้านห้วยฝาย.csv': ['outputs\\SO2_2010-2020\\บ้านห้วยฝาย.csv',
#   'outputs\\TEMP\\บ้านห้วยฝาย.csv',
#   'outputs\\WD\\บ้านห้วยฝาย.csv']}

# %%
import os
import pandas as pd

# Directory list
list_of_dirs = [
    'BP', 'DEV', 'NO2_2009-2019', 'PM10_2009-2019', 'RAIN', 'RH',
    'SO2_2009', 'SO2_2010-2020', 'SW', 'TEMP', 'TSP_2009-2019', 'WD', 'WS'
]

# Prepare a dictionary for merging directories with similar prefixes
dir_map = {
    'BP': ['BP'],
    'DEV': ['DEV'],
    'NO2': ['NO2_2009-2019'],
    'PM10': ['PM10_2009-2019'],
    'RAIN': ['RAIN'],
    'RH': ['RH'],
    'SO2': ['SO2_2009', 'SO2_2010-2020'],
    'SW': ['SW'],
    'TEMP': ['TEMP'],
    'TSP': ['TSP_2009-2019'],
    'WD': ['WD'],
    'WS': ['WS']
}

master_data = []

# Iterate over the directory map
for prefix, dirs in dir_map.items():
    for dirx in dirs:
        directory = os.path.join('outputs', dirx)
        files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.csv')]

        for file_path in files:
            df = pd.read_csv(file_path)
            # Add prefix to column names except for 'datetime', 'date', and 'hour'
            df.columns = [col if col in ['datetime', 'date', 'hour'] else prefix + "_" + col for col in df.columns]
            master_data.append(df)

# Concatenate all dataframes
master_df = pd.concat(master_data, axis=0, ignore_index=True)

# Save the master dataframe to a new CSV file
master_df
# Out:
#           BP_Year          BP_Datetime  BP_Value  BP_ValueLn  DEV_Year  \
# 0          2010.0  2010-01-01 01:00:00     964.0       964.0       NaN
# 1          2010.0  2010-01-01 02:00:00     964.0       964.0       NaN
# 2          2010.0  2010-01-01 03:00:00     963.0       963.0       NaN
# 3          2010.0  2010-01-01 04:00:00     963.0       963.0       NaN
# 4          2010.0  2010-01-01 05:00:00     963.0       963.0       NaN
# ...           ...                  ...       ...         ...       ...
# 11692435      NaN                  NaN       NaN         NaN       NaN
# 11692436      NaN                  NaN       NaN         NaN       NaN
# 11692437      NaN                  NaN       NaN         NaN       NaN
# 11692438      NaN                  NaN       NaN         NaN       NaN
# 11692439      NaN                  NaN       NaN         NaN       NaN
#
#          DEV_Datetime  DEV_Value  DEV_ValueLn  NO2_Year NO2_Datetime  ...  \
# 0                 NaN        NaN          NaN       NaN          NaN  ...
# 1                 NaN        NaN          NaN       NaN          NaN  ...
# 2                 NaN        NaN          NaN       NaN          NaN  ...
# 3                 NaN        NaN          NaN       NaN          NaN  ...
# 4                 NaN        NaN          NaN       NaN          NaN  ...
# ...               ...        ...          ...       ...          ...  ...
# 11692435          NaN        NaN          NaN       NaN          NaN  ...
# 11692436          NaN        NaN          NaN       NaN          NaN  ...
# 11692437          NaN        NaN          NaN       NaN          NaN  ...
# 11692438          NaN        NaN          NaN       NaN          NaN  ...
# 11692439          NaN        NaN          NaN       NaN          NaN  ...
#
#           TSP_Value  TSP_ValueLn  WD_Year WD_Datetime  WD_Value  WD_ValueLn  \
# 0               NaN          NaN      NaN         NaN       NaN         NaN
# 1               NaN          NaN      NaN         NaN       NaN         NaN
# 2               NaN          NaN      NaN         NaN       NaN         NaN
# 3               NaN          NaN      NaN         NaN       NaN         NaN
# 4               NaN          NaN      NaN         NaN       NaN         NaN
# ...             ...          ...      ...         ...       ...         ...
# 11692435        NaN          NaN      NaN         NaN       NaN         NaN
# 11692436        NaN          NaN      NaN         NaN       NaN         NaN
# 11692437        NaN          NaN      NaN         NaN       NaN         NaN
# 11692438        NaN          NaN      NaN         NaN       NaN         NaN
# 11692439        NaN          NaN      NaN         NaN       NaN         NaN
#
#           WS_Year          WS_Datetime  WS_Value  WS_ValueLn
# 0             NaN                  NaN       NaN         NaN
# 1             NaN                  NaN       NaN         NaN
# 2             NaN                  NaN       NaN         NaN
# 3             NaN                  NaN       NaN         NaN
# 4             NaN                  NaN       NaN         NaN
# ...           ...                  ...       ...         ...
# 11692435   2020.0  2020-12-31 20:00:00      0.33        0.33
# 11692436   2020.0  2020-12-31 21:00:00      0.17        0.17
# 11692437   2020.0  2020-12-31 22:00:00      0.26        0.26
# 11692438   2020.0  2020-12-31 23:00:00      0.40        0.40
# 11692439   2021.0  2021-01-01 00:00:00      0.42        0.42
#
# [11692440 rows x 48 columns]

# %%
import os
import pandas as pd

# Placeholder for the list of dataframes to be merged
dfs = []

for dirx in list_of_dirs:
    # Extract the base pollutant name (prefix before underscore)
    prefix = dirx.split('_')[0]

    directory = os.path.join('outputs', dirx)
    files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.csv')]

    for file_path in files:
        df = pd.read_csv(file_path)

        # Rename the 'Value' column to the prefix and drop the 'ValueLn' column
        df[prefix] = df['Value']
        df = df.drop(columns=['Value', 'ValueLn'])

        dfs.append(df)

# Merge all dataframes on 'Year' and 'Datetime'
final_df = dfs[0]
for df in dfs[1:]:
    final_df = pd.merge(final_df, df, on=['Year', 'Datetime'], how='outer')

# Save the merged dataframe
final_df
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[32], line 26
#      24 final_df = dfs[0]
#      25 for df in dfs[1:]:
# ---> 26     final_df = pd.merge(final_df, df, on=['Year', 'Datetime'], how='outer')
#      28 # Save the merged dataframe
#      29 final_df
#
# File D:\Users\User\anaconda3\envs\thesis-may\lib\site-packages\pandas\core\reshape\merge.py:183, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168 else:
#     169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#    (...)
#     181         validate=validate,
#     182     )
# --> 183     return op.get_result(copy=copy)
#
# File D:\Users\User\anaconda3\envs\thesis-may\lib\site-packages\pandas\core\reshape\merge.py:885, in _MergeOperation.get_result(self, copy)
#     881     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     883 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 885 result = self._reindex_and_concat(
#     886     join_index, left_indexer, right_indexer, copy=copy
#     887 )
#     888 result = result.__finalize__(self, method=self._merge_type)
#     890 if self.indicator:
#
# File D:\Users\User\anaconda3\envs\thesis-may\lib\site-packages\pandas\core\reshape\merge.py:837, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     834 left = self.left[:]
#     835 right = self.right[:]
# --> 837 llabels, rlabels = _items_overlap_with_suffix(
#     838     self.left._info_axis, self.right._info_axis, self.suffixes
#     839 )
#     841 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     842     # Pinning the index here (and in the right code just below) is not
#     843     #  necessary, but makes the `.take` more performant if we have e.g.
#     844     #  a MultiIndex for left.index.
#     845     lmgr = left._mgr.reindex_indexer(
#     846         join_index,
#     847         left_indexer,
#    (...)
#     852         use_na_proxy=True,
#     853     )
#
# File D:\Users\User\anaconda3\envs\thesis-may\lib\site-packages\pandas\core\reshape\merge.py:2691, in _items_overlap_with_suffix(left, right, suffixes)
#    2689     dups.extend(rlabels[(rlabels.duplicated()) & (~right.duplicated())].tolist())
#    2690 if dups:
# -> 2691     raise MergeError(
#    2692         f"Passing 'suffixes' which cause duplicate columns {set(dups)} is "
#    2693         f"not allowed.",
#    2694     )
#    2696 return llabels, rlabels
#
# MergeError: Passing 'suffixes' which cause duplicate columns {'BP_x'} is not allowed.

# %%
import os
import pandas as pd

# Dictionary to hold dataframes
dfs = {}

for dirx in list_of_dirs:
    # Extracting the column name from directory name
    if "_" in dirx:
        col_name = dirx.split("_")[0]
    else:
        col_name = dirx

    # list csv files in the directory
    directory = os.path.join('outputs', dirx)
    files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.csv')]

    # Read and merge files from the same directory
    dir_dfs = [pd.read_csv(file) for file in files]
    dir_df = pd.concat(dir_dfs, ignore_index=True)

    # If the column name already exists, we sum the data, else we just assign
    if col_name in dfs:
        dfs[col_name] = dfs[col_name].add(dir_df, fill_value=0)
    else:
        dfs[col_name] = dir_df

# Joining on 'Year,Datetime'
final_df = dfs.pop('Year,Datetime')  # Start with 'Year,Datetime' dataframe
for col_name, df in dfs.items():
    final_df = final_df.merge(df[['Year', 'Datetime', col_name]], on=['Year', 'Datetime'], how='outer')

# Save the merged dataframe
final_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19076\3216125443.py in ?()
#      20     # list csv files in the directory
#      21     directory = os.path.join('outputs', dirx)
#      22     files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.csv')]
#      23
# ---> 24     # Read and merge files from the same directory
#      25     dir_dfs = [pd.read_csv(file) for file in files]
#      26     dir_df = pd.concat(dir_dfs, ignore_index=True)
#      27
#
# D:\Users\User\anaconda3\envs\thesis-may\lib\site-packages\pandas\core\frame.py in ?(self, other, axis, level, fill_value)
#    8079     @Appender(ops.make_flex_doc("add", "dataframe"))
#    8080     def add(self, other, axis: Axis = "columns", level=None, fill_value=None):
# -> 8081         return self._flex_arith_method(
#    8082             other, operator.add, level=level, fill_value=fill_value, axis=axis
#    8083         )
#
# D:\Users\User\anaconda3\envs\thesis-may\lib\site-packages\pandas\core\frame.py in ?(self, other, op, axis, level, fill_value)
#    8008                 # in this case we always have `np.ndim(other) == 0`
#    8009                 if fill_value is not None:
#    8010                     self = self.fillna(fill_value)
#    8011
# -> 8012                 new_data = self._dispatch_frame_op(other, op)
#    8013
#    8014         return self._construct_result(new_data)
#
# D:\Users\User\anaconda3\envs\thesis-may\lib\site-packages\pandas\core\frame.py in ?(self, other, func, fill_value)
#    7741                 # left._binop(right, func, fill_value=fill_value)
#    7742                 left, right = ops.fill_binop(left, right, fill_value)
#    7743                 return func(left, right)
#    7744
# -> 7745         new_data = self._dispatch_frame_op(other, _arith_op)
#    7746         return new_data
#
# D:\Users\User\anaconda3\envs\thesis-may\lib\site-packages\pandas\core\frame.py in ?(self, right, func, axis)
#    7686             #  fails in cases with empty columns reached via
#    7687             #  _frame_arith_method_with_reindex
#    7688
#    7689             # TODO operate_blockwise expects a manager of the same type
# -> 7690             bm = self._mgr.operate_blockwise(
#    7691                 # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    7692                 # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7693                 # "ArrayManager"
#
# D:\Users\User\anaconda3\envs\thesis-may\lib\site-packages\pandas\core\internals\managers.py in ?(self, other, array_op)
#    1466     def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1467         """
#    1468         Apply array_op blockwise with another (aligned) BlockManager.
#    1469         """
# -> 1470         return operate_blockwise(self, other, array_op)
#
# D:\Users\User\anaconda3\envs\thesis-may\lib\site-packages\pandas\core\internals\ops.py in ?(left, right, array_op)
#      61     #  assert rframe._indexed_same(lframe)
#      62
#      63     res_blks: list[Block] = []
#      64     for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 65         res_values = array_op(lvals, rvals)
#      66         if (
#      67             left_ea
#      68             and not right_ea
#
# D:\Users\User\anaconda3\envs\thesis-may\lib\site-packages\pandas\core\frame.py in ?(left, right)
#    7739                 # for the mixed_type case where we iterate over columns,
#    7740                 # _arith_op(left, right) is equivalent to
#    7741                 # left._binop(right, func, fill_value=fill_value)
#    7742                 left, right = ops.fill_binop(left, right, fill_value)
# -> 7743                 return func(left, right)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
